# %%
import os, json
import pandas as pd
import numpy as np
import seaborn as sn

import matplotlib.pyplot as plt
import numpy.linalg as nla

# display graphics in the browser window
# "cell magics"  %%
# "line magics" % 
# %matplotlib inline

# %%
# read in the dataset
def get_movies(aDir):
    import os, json
    file_contents = os.listdir(aDir)

    movie_list = []

    for filename in file_contents:
        filepath = os.path.join(aDir, filename)

        if not filename.endswith(".json"):
            continue
        
        with open(filepath, 'r') as movie_file:
            movie_data = json.load(movie_file)
        if hasattr(movie_data, "keys"): # type(movie_data) == dict:
            movie_list.append(movie_data)
    return movie_list

# %%
movie_list = get_movies("C:/Users/abd487/Documents/Trainings/Data Science Boot Camp/Movies/project_1/data/metacritic/")
critics = pd.DataFrame(movie_list)
critics.head()
# Out:
#   complete         director                        genre  \
# 0     True       Gil Junger            [Comedy, Romance]
# 1     True     Jamie Linden     [Drama, Comedy, Romance]
# 2     True  Roland Emmerich  [Adventure, Drama, Fantasy]
# 3     True    Stephen Herek  [Adventure, Comedy, Family]
# 4     True       Kevin Lima             [Comedy, Family]
#
#                      metacritic_page  metascore num_critic_reviews  \
# 0  /movie/10-things-i-hate-about-you       70.0     [18, 7, 1, 26]
# 1                    /movie/10-years       61.0     [7, 11, 0, 18]
# 2                    /movie/10000-bc       34.0     [4, 8, 17, 29]
# 3              /movie/101-dalmatians       49.0      [8, 9, 3, 20]
# 4              /movie/102-dalmatians       35.0     [7, 5, 12, 24]
#
#    num_user_ratings   num_user_reviews rating release_date  runtime_minutes  \
# 0             175.0     [27, 1, 1, 29]  PG-13   1999-03-31             97.0
# 1              12.0       [3, 2, 1, 6]      R   2012-09-14            100.0
# 2             273.0  [50, 18, 60, 128]  PG-13   2008-03-07            109.0
# 3              78.0      [5, 5, 0, 10]      G   1996-11-27            103.0
# 4              47.0      [7, 3, 3, 13]      G   2000-11-22            100.0
#
#                      studio                       title unable to retrieve  \
# 0      Buena Vista Pictures  10 Things I Hate About You                NaN
# 1  Anchor Bay Entertainment                    10 Years                NaN
# 2     Warner Bros. Pictures                   10,000 BC                NaN
# 3      Buena Vista Pictures              101 Dalmatians                NaN
# 4      Buena Vista Pictures              102 Dalmatians                NaN
#
#   user_score  year
# 0          7  1999
# 1        6.6  2012
# 2        4.6  2008
# 3        5.9  1996
# 4        5.3  2000

# %%
movie_list = get_movies("C:/Users/abd487/Documents/Trainings/Data Science Boot Camp/Movies/project_1/data/boxofficemojo/")
movies = pd.DataFrame(movie_list)
movies.head()
# Out:
#                            alt_title         director  domestic_gross  \
# 0                 10,000 B.C. (2008)  Roland Emmerich      94784201.0
# 1              102 Dalmatians (2000)             None      66957026.0
# 2  10 Things I Hate About You (1999)             None      38178166.0
# 3                    10 Years (2012)     Jamie Linden        203373.0
# 4                  11 Flowers (2013)             None          9213.0
#
#                mojo_slug  opening_per_theater  opening_weekend_take  \
# 0                10000bc              10518.0            35867488.0
# 1          102dalmatians               7353.0            19883351.0
# 2  10thingsihateaboutyou               3668.0             8330681.0
# 3                10years               7569.0               22707.0
# 4              11flowers               1758.0                3516.0
#
#    production_budget release_date_limited release_date_wide  \
# 0        105000000.0                 None        2008-03-07
# 1         85000000.0                 None        2000-11-22
# 2         30000000.0                 None        1999-03-31
# 3                NaN                 None        2012-09-14
# 4                NaN                 None        2013-02-22
#
#                         title  widest_release  worldwide_gross    year
# 0                 10,000 B.C.          3454.0      269784201.0  2008.0
# 1             102 Dalmatians           2704.0      183611771.0  2000.0
# 2  10 Things I Hate About You          2311.0       53478166.0  1999.0
# 3                    10 Years            63.0         203373.0  2012.0
# 4                 11 Flowers              2.0              NaN  2013.0

# %%
# add dummy vr to flag out movies in the original box dataset
movies.loc[:,'box_flag'] = 1

# %%
critics['title1']=critics['title'].fillna('z')

# %%
critics['title1'] = map(lambda x: x.lower(), critics['title1'])

# %%
critics.loc[:,'mojo_slug']=critics['title1'].str.replace(' ', '')
critics['mojo_slug']=critics['mojo_slug'].str.replace('.', '')
critics['mojo_slug']=critics['mojo_slug'].str.replace(',', '')

# %%
critics=critics.drop('title1', axis=1)

# %%
critics['year']=critics['year'].fillna(0)

# %%
movies['year']=movies['year'].fillna(0)

# %%
movies['year']=movies['year'].astype(int)

# %%
critics['key'] = critics['mojo_slug'].str.cat(critics['year'].values.astype(str))
movies['key'] = movies['mojo_slug'].str.cat(movies['year'].values.astype(str))

# %%
movies_crictics_df=pd.merge(movies, critics, on=('key'), how='outer')

# %%
movies_crictics_df.head()
# Out:
#                            alt_title       director_x  domestic_gross  \
# 0                 10,000 B.C. (2008)  Roland Emmerich      94784201.0
# 1              102 Dalmatians (2000)             None      66957026.0
# 2  10 Things I Hate About You (1999)             None      38178166.0
# 3                    10 Years (2012)     Jamie Linden        203373.0
# 4                  11 Flowers (2013)             None          9213.0
#
#              mojo_slug_x  opening_per_theater  opening_weekend_take  \
# 0                10000bc              10518.0            35867488.0
# 1          102dalmatians               7353.0            19883351.0
# 2  10thingsihateaboutyou               3668.0             8330681.0
# 3                10years               7569.0               22707.0
# 4              11flowers               1758.0                3516.0
#
#    production_budget release_date_limited release_date_wide  \
# 0        105000000.0                 None        2008-03-07
# 1         85000000.0                 None        2000-11-22
# 2         30000000.0                 None        1999-03-31
# 3                NaN                 None        2012-09-14
# 4                NaN                 None        2013-02-22
#
#                       title_x          ...             num_user_reviews  \
# 0                 10,000 B.C.          ...            [50, 18, 60, 128]
# 1             102 Dalmatians           ...                [7, 3, 3, 13]
# 2  10 Things I Hate About You          ...               [27, 1, 1, 29]
# 3                    10 Years          ...                 [3, 2, 1, 6]
# 4                 11 Flowers           ...                 [1, 0, 0, 1]
#
#       rating  release_date  runtime_minutes                    studio  \
# 0      PG-13    2008-03-07            109.0     Warner Bros. Pictures
# 1          G    2000-11-22            100.0      Buena Vista Pictures
# 2      PG-13    1999-03-31             97.0      Buena Vista Pictures
# 3          R    2012-09-14            100.0  Anchor Bay Entertainment
# 4  Not Rated    2013-02-22            110.0        First Run Features
#
#                       title_y unable to retrieve user_score year_y  \
# 0                   10,000 BC                NaN        4.6   2008
# 1              102 Dalmatians                NaN        5.3   2000
# 2  10 Things I Hate About You                NaN          7   1999
# 3                    10 Years                NaN        6.6   2012
# 4                  11 Flowers                NaN        tbd   2013
#
#              mojo_slug_y
# 0                10000bc
# 1          102dalmatians
# 2  10thingsihateaboutyou
# 3                10years
# 4              11flowers
#
# [5 rows x 32 columns]

# %%
def get_award_data_dir():
    '''
    Quick function to leverage os functions to identify the base 'data'
    directory, for use in the subsequent explicit directory pulls
    '''
    CURRENT_DIR = os.path.dirname(os.path.realpath(__file__))
    DATA_DIR = os.path.abspath(os.path.join(CURRENT_DIR, 'data'))
    return os.path.join(DATA_DIR, 'awards')

# %%
def load_award_data():
    award_file = os.path.abspath(os.path.join(get_award_data_dir(),'academy_awards.csv'))
    with open(award_file, 'r') as csv_file:
        award_data = pd.read_csv(csv_file)

    return award_data

# %%
def award_categories():
    major_award_categories = ['Directing',
                          'Best Picture',
                          'Actress -- Leading Role',
                          'Actor -- Leading Role',
                         'Cinematography']
    return major_award_categories

# %%
def clean_raw_award_data(award_df):
    return award_df[['Year','Category','Nominee','Additional Info','Won?']]

# %%
def clean_updated_award_df(award_df):
    new_df = award_df[['Film','Year_Num','Category','NO','YES','Nominee']]
    new_df.rename(columns={'Year_Num' : 'Year'}, inplace=True )
    return new_df

# %%
def restrict_to_major_awards(award_df):
    return award_df[award_df['Category'].isin(award_categories())].reset_index()

# %%
def add_result_flags(award_df):
    winners = pd.get_dummies(award_df['Won?'])
    return pd.concat([award_df,winners],axis=1)

# %%
def film_from_additional(row):
     # add a "Film" column to df
    additional_info_txt = row['Additional Info']
    text_info = str(additional_info_txt)
    film = text_info.split('{')
    film_txt = film[0].strip()
    return film_txt

# %%
def nominee_is_film(row):
    nominee_txt = row['Nominee']
    return nominee_txt.strip()

# %%
def get_category_functions():
    '''
    Each of the functions that are the values must be defined above this!
    '''
    return {'Actor -- Leading Role':film_from_additional,
                 'Actress -- Leading Role':film_from_additional,
                 'Cinematography':nominee_is_film,
                 'Directing':nominee_is_film,
                 'Best Picture':nominee_is_film}

# %%
def get_film(df_row):
    cat_functions = get_category_functions()
    return cat_functions[df_row.Category](df_row)

# %%
def add_film_name_to_df(award_df):
    award_df['Film'] = award_df.apply(get_film, axis=1)
    return award_df

# %%
def get_year_num(df_row):
    if ' ' in df_row['Year']:
        year_txt = df_row['Year'].split(' ')
    else:
        year_txt = None
    return year_txt[0]

# %%
def add_clean_year_to_df(award_df):
    award_df['Year_Num'] = award_df.apply(get_year_num, axis=1)
    return award_df

# %%
def get_awards_data():
     raw_data = load_award_data()
     clean_raw_data = clean_raw_award_data(raw_data)
     major_award_data = restrict_to_major_awards(clean_raw_data)
     major_awards_with_results = add_result_flags(major_award_data)
     major_with_film = add_film_name_to_df(major_awards_with_results)
     major_with_film_and_year = add_clean_year_to_df(major_with_film)
     final_award_data = clean_updated_award_df(major_with_film_and_year)
     print "Award data contains " + str(len(final_award_data))
     return final_award_data

# %%
    award_file = "C:/Users/abd487/Documents/Trainings/Data Science Boot Camp/Movies/project_1/data//awards/academy_awards.csv"
    with open(award_file, 'r') as csv_file:
        award_data = pd.read_csv(csv_file)

# %%
award_data.head()
# Out:
#           Year               Category          Nominee  \
# 0  2010 (83rd)  Actor -- Leading Role    Javier Bardem
# 1  2010 (83rd)  Actor -- Leading Role     Jeff Bridges
# 2  2010 (83rd)  Actor -- Leading Role  Jesse Eisenberg
# 3  2010 (83rd)  Actor -- Leading Role      Colin Firth
# 4  2010 (83rd)  Actor -- Leading Role     James Franco
#
#                           Additional Info Won? Unnamed: 5 Unnamed: 6  \
# 0                      Biutiful {'Uxbal'}   NO        NaN        NaN
# 1           True Grit {'Rooster Cogburn'}   NO        NaN        NaN
# 2  The Social Network {'Mark Zuckerberg'}   NO        NaN        NaN
# 3    The King's Speech {'King George VI'}  YES        NaN        NaN
# 4              127 Hours {'Aron Ralston'}   NO        NaN        NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10
# 0        NaN        NaN        NaN         NaN
# 1        NaN        NaN        NaN         NaN
# 2        NaN        NaN        NaN         NaN
# 3        NaN        NaN        NaN         NaN
# 4        NaN        NaN        NaN         NaN

# %%
award_data_clean=award_data[['Year','Category','Nominee','Additional Info','Won?']]

# %%
    major_award_categories = ['Directing',
                          'Best Picture',
                          'Actress -- Leading Role',
                          'Actor -- Leading Role',
                         'Cinematography']
awards_major=award_data_clean[award_data_clean['Category'].isin(major_award_categories)].reset_index()

# %%
awards_major.head()
# Out:
#    index         Year               Category          Nominee  \
# 0      0  2010 (83rd)  Actor -- Leading Role    Javier Bardem
# 1      1  2010 (83rd)  Actor -- Leading Role     Jeff Bridges
# 2      2  2010 (83rd)  Actor -- Leading Role  Jesse Eisenberg
# 3      3  2010 (83rd)  Actor -- Leading Role      Colin Firth
# 4      4  2010 (83rd)  Actor -- Leading Role     James Franco
#
#                           Additional Info Won?
# 0                      Biutiful {'Uxbal'}   NO
# 1           True Grit {'Rooster Cogburn'}   NO
# 2  The Social Network {'Mark Zuckerberg'}   NO
# 3    The King's Speech {'King George VI'}  YES
# 4              127 Hours {'Aron Ralston'}   NO

# %%
winners = pd.get_dummies(awards_major['Won?'])
winners_results= pd.concat([awards_major,winners],axis=1)

# %%
winners_results.head()
# Out:
#    index         Year               Category          Nominee  \
# 0      0  2010 (83rd)  Actor -- Leading Role    Javier Bardem
# 1      1  2010 (83rd)  Actor -- Leading Role     Jeff Bridges
# 2      2  2010 (83rd)  Actor -- Leading Role  Jesse Eisenberg
# 3      3  2010 (83rd)  Actor -- Leading Role      Colin Firth
# 4      4  2010 (83rd)  Actor -- Leading Role     James Franco
#
#                           Additional Info Won?   NO  YES
# 0                      Biutiful {'Uxbal'}   NO  1.0  0.0
# 1           True Grit {'Rooster Cogburn'}   NO  1.0  0.0
# 2  The Social Network {'Mark Zuckerberg'}   NO  1.0  0.0
# 3    The King's Speech {'King George VI'}  YES  0.0  1.0
# 4              127 Hours {'Aron Ralston'}   NO  1.0  0.0

# %%
winners_results['Film'] = winners_results.apply(get_film, axis=1)

# %%
winners_results.head()
# Out:
#    index         Year               Category          Nominee  \
# 0      0  2010 (83rd)  Actor -- Leading Role    Javier Bardem
# 1      1  2010 (83rd)  Actor -- Leading Role     Jeff Bridges
# 2      2  2010 (83rd)  Actor -- Leading Role  Jesse Eisenberg
# 3      3  2010 (83rd)  Actor -- Leading Role      Colin Firth
# 4      4  2010 (83rd)  Actor -- Leading Role     James Franco
#
#                           Additional Info Won?   NO  YES                Film
# 0                      Biutiful {'Uxbal'}   NO  1.0  0.0            Biutiful
# 1           True Grit {'Rooster Cogburn'}   NO  1.0  0.0           True Grit
# 2  The Social Network {'Mark Zuckerberg'}   NO  1.0  0.0  The Social Network
# 3    The King's Speech {'King George VI'}  YES  0.0  1.0   The King's Speech
# 4              127 Hours {'Aron Ralston'}   NO  1.0  0.0           127 Hours

# %%
major_with_film_and_year = add_clean_year_to_df(winners_results)

# %%
major_with_film_and_year.head()
# Out:
#    index         Year               Category          Nominee  \
# 0      0  2010 (83rd)  Actor -- Leading Role    Javier Bardem
# 1      1  2010 (83rd)  Actor -- Leading Role     Jeff Bridges
# 2      2  2010 (83rd)  Actor -- Leading Role  Jesse Eisenberg
# 3      3  2010 (83rd)  Actor -- Leading Role      Colin Firth
# 4      4  2010 (83rd)  Actor -- Leading Role     James Franco
#
#                           Additional Info Won?   NO  YES                Film  \
# 0                      Biutiful {'Uxbal'}   NO  1.0  0.0            Biutiful
# 1           True Grit {'Rooster Cogburn'}   NO  1.0  0.0           True Grit
# 2  The Social Network {'Mark Zuckerberg'}   NO  1.0  0.0  The Social Network
# 3    The King's Speech {'King George VI'}  YES  0.0  1.0   The King's Speech
# 4              127 Hours {'Aron Ralston'}   NO  1.0  0.0           127 Hours
#
#   Year_Num
# 0     2010
# 1     2010
# 2     2010
# 3     2010
# 4     2010

# %%
final_award_data=major_with_film_and_year[['Film','Year_Num','Category','NO','YES','Nominee']]
#final_award_data=new_df.rename(columns={'Year_Num' : 'Year'}, inplace=True )

# %%
final_award_data=final_award_data.rename(columns={'Year_num' :'Year'}, inplace=True)

# %%
final_award_data.head()
# Out:
#                  Film Year_Num               Category   NO  YES  \
# 0            Biutiful     2010  Actor -- Leading Role  1.0  0.0
# 1           True Grit     2010  Actor -- Leading Role  1.0  0.0
# 2  The Social Network     2010  Actor -- Leading Role  1.0  0.0
# 3   The King's Speech     2010  Actor -- Leading Role  0.0  1.0
# 4           127 Hours     2010  Actor -- Leading Role  1.0  0.0
#
#            Nominee
# 0    Javier Bardem
# 1     Jeff Bridges
# 2  Jesse Eisenberg
# 3      Colin Firth
# 4     James Franco

# %%
final_award_data.count()
# Out:
# Film        2286
# Year_Num    2286
# Category    2286
# NO          2286
# YES         2286
# Nominee     2286
# dtype: int64

# %%
final_award_data
# Out:
#                                                    Film Year_Num  \
# 0                                              Biutiful     2010
# 1                                             True Grit     2010
# 2                                    The Social Network     2010
# 3                                     The King's Speech     2010
# 4                                             127 Hours     2010
# 5                                The Kids Are All Right     2010
# 6                                           Rabbit Hole     2010
# 7                                         Winter's Bone     2010
# 8                                            Black Swan     2010
# 9                                        Blue Valentine     2010
# 10                                           Black Swan     2010
# 11                                            Inception     2010
# 12                                    The King's Speech     2010
# 13                                   The Social Network     2010
# 14                                            True Grit     2010
# 15                                           Black Swan     2010
# 16                                          The Fighter     2010
# 17                                    The King's Speech     2010
# 18                                   The Social Network     2010
# 19                                            True Grit     2010
# 20                                           Black Swan     2010
# 21                                          The Fighter     2010
# 22                                            Inception     2010
# 23                               The Kids Are All Right     2010
# 24                                    The King's Speech     2010
# 25                                            127 Hours     2010
# 26                                   The Social Network     2010
# 27                                          Toy Story 3     2010
# 28                                            True Grit     2010
# 29                                        Winter's Bone     2010
# ...                                                 ...      ...
# 2256                                         John Seitz  1928/29
# 2257                                   Lionel Barrymore  1928/29
# 2258                                     Harry Beaumont  1928/29
# 2259                                    Irving Cummings  1928/29
# 2260                                        Frank Lloyd  1928/29
# 2261                                        Frank Lloyd  1928/29
# 2262                                     Ernst Lubitsch  1928/29
# 2263                                Feature Productions  1928/29
# 2264                                                Fox  1928/29
# 2265                                Metro-Goldwyn-Mayer  1928/29
# 2266                                Metro-Goldwyn-Mayer  1928/29
# 2267                             Paramount Famous Lasky  1928/29
# 2268                                          The Noose  1927/28
# 2269                                   The Last Command  1927/28
# 2270                                                nan  1927/28
# 2271                                    A Ship Comes In  1927/28
# 2272                                         7th Heaven  1927/28
# 2273                                     Sadie Thompson  1927/28
# 2274                                      George Barnes  1927/28
# 2275                                     Charles Rosher  1927/28
# 2276                                        Karl Struss  1927/28
# 2277                                    Lewis Milestone  1927/28
# 2278                                          Ted Wilde  1927/28
# 2279                                      Frank Borzage  1927/28
# 2280                                     Herbert Brenon  1927/28
# 2281                                         King Vidor  1927/28
# 2282  To Charles Chaplin, for acting, writing, direc...  1927/28
# 2283                                  The Caddo Company  1927/28
# 2284                                                Fox  1927/28
# 2285                             Paramount Famous Lasky  1927/28
#
#                      Category   NO  YES  \
# 0       Actor -- Leading Role  1.0  0.0
# 1       Actor -- Leading Role  1.0  0.0
# 2       Actor -- Leading Role  1.0  0.0
# 3       Actor -- Leading Role  0.0  1.0
# 4       Actor -- Leading Role  1.0  0.0
# 5     Actress -- Leading Role  1.0  0.0
# 6     Actress -- Leading Role  1.0  0.0
# 7     Actress -- Leading Role  1.0  0.0
# 8     Actress -- Leading Role  0.0  1.0
# 9     Actress -- Leading Role  1.0  0.0
# 10             Cinematography  1.0  0.0
# 11             Cinematography  0.0  1.0
# 12             Cinematography  1.0  0.0
# 13             Cinematography  1.0  0.0
# 14             Cinematography  1.0  0.0
# 15                  Directing  1.0  0.0
# 16                  Directing  1.0  0.0
# 17                  Directing  0.0  1.0
# 18                  Directing  1.0  0.0
# 19                  Directing  1.0  0.0
# 20               Best Picture  1.0  0.0
# 21               Best Picture  1.0  0.0
# 22               Best Picture  1.0  0.0
# 23               Best Picture  1.0  0.0
# 24               Best Picture  0.0  1.0
# 25               Best Picture  1.0  0.0
# 26               Best Picture  1.0  0.0
# 27               Best Picture  1.0  0.0
# 28               Best Picture  1.0  0.0
# 29               Best Picture  1.0  0.0
# ...                       ...  ...  ...
# 2256           Cinematography  1.0  0.0
# 2257                Directing  1.0  0.0
# 2258                Directing  1.0  0.0
# 2259                Directing  1.0  0.0
# 2260                Directing  0.0  1.0
# 2261                Directing  1.0  0.0
# 2262                Directing  1.0  0.0
# 2263             Best Picture  1.0  0.0
# 2264             Best Picture  1.0  0.0
# 2265             Best Picture  0.0  1.0
# 2266             Best Picture  1.0  0.0
# 2267             Best Picture  1.0  0.0
# 2268    Actor -- Leading Role  1.0  0.0
# 2269    Actor -- Leading Role  0.0  1.0
# 2270    Actor -- Leading Role  0.0  1.0
# 2271  Actress -- Leading Role  1.0  0.0
# 2272  Actress -- Leading Role  0.0  1.0
# 2273  Actress -- Leading Role  1.0  0.0
# 2274           Cinematography  1.0  0.0
# 2275           Cinematography  0.0  1.0
# 2276           Cinematography  0.0  1.0
# 2277                Directing  0.0  1.0
# 2278                Directing  1.0  0.0
# 2279                Directing  0.0  1.0
# 2280                Directing  1.0  0.0
# 2281                Directing  1.0  0.0
# 2282                Directing  0.0  1.0
# 2283             Best Picture  1.0  0.0
# 2284             Best Picture  1.0  0.0
# 2285             Best Picture  0.0  1.0
#
#                                                 Nominee
# 0                                         Javier Bardem
# 1                                          Jeff Bridges
# 2                                       Jesse Eisenberg
# 3                                           Colin Firth
# 4                                          James Franco
# 5                                        Annette Bening
# 6                                         Nicole Kidman
# 7                                     Jennifer Lawrence
# 8                                       Natalie Portman
# 9                                     Michelle Williams
# 10                                           Black Swan
# 11                                            Inception
# 12                                    The King's Speech
# 13                                   The Social Network
# 14                                            True Grit
# 15                                           Black Swan
# 16                                          The Fighter
# 17                                    The King's Speech
# 18                                   The Social Network
# 19                                            True Grit
# 20                                           Black Swan
# 21                                          The Fighter
# 22                                            Inception
# 23                               The Kids Are All Right
# 24                                    The King's Speech
# 25                                            127 Hours
# 26                                   The Social Network
# 27                                          Toy Story 3
# 28                                            True Grit
# 29                                        Winter's Bone
# ...                                                 ...
# 2256                                         John Seitz
# 2257                                   Lionel Barrymore
# 2258                                     Harry Beaumont
# 2259                                    Irving Cummings
# 2260                                        Frank Lloyd
# 2261                                        Frank Lloyd
# 2262                                     Ernst Lubitsch
# 2263                                Feature Productions
# 2264                                                Fox
# 2265                                Metro-Goldwyn-Mayer
# 2266                                Metro-Goldwyn-Mayer
# 2267                             Paramount Famous Lasky
# 2268                                Richard Barthelmess
# 2269                                      Emil Jannings
# 2270  To Charles Chaplin, for acting, writing, direc...
# 2271                                     Louise Dresser
# 2272                                       Janet Gaynor
# 2273                                     Gloria Swanson
# 2274                                      George Barnes
# 2275                                     Charles Rosher
# 2276                                        Karl Struss
# 2277                                    Lewis Milestone
# 2278                                          Ted Wilde
# 2279                                      Frank Borzage
# 2280                                     Herbert Brenon
# 2281                                         King Vidor
# 2282  To Charles Chaplin, for acting, writing, direc...
# 2283                                  The Caddo Company
# 2284                                                Fox
# 2285                             Paramount Famous Lasky
#
# [2286 rows x 6 columns]

# %%
final_award_data['film'].value_counts
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-890813905b64> in <module>()
# ----> 1 final_award_data['film'].value_counts
#
# C:\Users\abd487\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1990             return self._getitem_multilevel(key)
#    1991         else:
# -> 1992             return self._getitem_column(key)
#    1993
#    1994     def _getitem_column(self, key):
#
# C:\Users\abd487\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    1997         # get column
#    1998         if self.columns.is_unique:
# -> 1999             return self._get_item_cache(key)
#    2000
#    2001         # duplicate columns & possible reduce dimensionality
#
# C:\Users\abd487\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\generic.pyc in _get_item_cache(self, item)
#    1343         res = cache.get(item)
#    1344         if res is None:
# -> 1345             values = self._data.get(item)
#    1346             res = self._box_item_values(item, values)
#    1347             cache[item] = res
#
# C:\Users\abd487\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\internals.pyc in get(self, item, fastpath)
#    3223
#    3224             if not isnull(item):
# -> 3225                 loc = self.items.get_loc(item)
#    3226             else:
#    3227                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\abd487\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\indexes\base.pyc in get_loc(self, key, method, tolerance)
#    1876                 return self._engine.get_loc(key)
#    1877             except KeyError:
# -> 1878                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1879
#    1880         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4027)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:3891)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12408)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12359)()
#
# KeyError: 'film'
